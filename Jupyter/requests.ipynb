# %% [markdown]
# # Requests notes

# %% [markdown]
# ## Installation of Requests

# %% [markdown]
# ```shell
# python pip install requests
# ```

# %% [markdown]
# ## quick startks

# %% [markdown]
# ### 导入模块

# %%
import requests

# %% [markdown]
# ### get 请求

# %%
r_get = requests.get('https://api.github.com/events')
print(r_get)
# Out:
# <Response [200]>

# %% [markdown]
# ## post 请求

# %% [markdown]
# ### 直接传递参数

# %%
r_post = requests.post('https://httpbin.org/post', data={'key': 'value'})

# %% [markdown]
# ### 使用字典传递参数

# %%
payload = {'name': 'kelvin', 'age': 18}
r_post = requests.post('https://httpbin.org/post', params=payload)
print(r_post.url)
# Out:
# https://httpbin.org/post?name=kelvin&age=18

# %% [markdown]
# ## 一些其他请求方法

# %%
r_put = requests.put('https://httpbin.org/put', data={'key': 'value'})
r_delete = requests.delete('https://httpbin.org/delete')
r_head = requests.head('https://httpbin.org/get')
r_option = requests.options('https://httpbin.org/get')

# %% [markdown]
# ## 打印编码方式和更改编码方式

# %%
r_get.encoding
# Out:
# 'utf-8'

# %%
r = r_get
r.encoding = 'ISO-8859-1'
r.encoding
r.encoding = 'UTF-8'

# %% [markdown]
# ## 响应字符内容

# %%
r_get.text
# Out:
# '[{"id":"18215875178","type":"ReleaseEvent","actor":{"id":48498042,"login":"juliancasaburi","display_login":"juliancasaburi","gravatar_id":"","url":"https://api.github.com/users/juliancasaburi","avatar_url":"https://avatars.githubusercontent.com/u/48498042?"},"repo":{"id":411911781,"name":"juliancasaburi/flysystem-google-drive-ext","url":"https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext"},"payload":{"action":"published","release":{"url":"https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext/releases/50520418","assets_url":"https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext/releases/50520418/assets","upload_url":"https://uploads.github.com/repos/juliancasaburi/flysystem-google-drive-ext/releases/50520418/assets{?name,label}","html_url":"https://github.com/juliancasaburi/flysystem-google-drive-ext/releases/tag/1.2.3b","id":50520418,"author":{"login":"juliancasaburi","id":48498042,"node_id":"MDQ6VXNlcjQ4NDk4MDQy","avatar_url":"https://avatars.githubusercontent.com/u/48498042?v=4","gravatar_id":"","url":"https://api.github.com/users/juliancasaburi","html_url":"https://github.com/juliancasaburi","followers_url":"https://api.github.com/users/juliancasaburi/followers","following_url":"https://api.github.com/users/juliancasaburi/following{/other_user}","gists_url":"https://api.github.com/users/juliancasaburi/gists{/gist_id}","starred_url":"https://api.github.com/users/juliancasaburi/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/juliancasaburi/subscriptions","organizations_url":"https://api.github.com/users/juliancasaburi/orgs","repos_url":"https://api.github.com/users/juliancasaburi/repos","events_url":"https://api.github.com/users/juliancasaburi/events{/privacy}","received_events_url":"https://api.github.com/users/juliancasaburi/received_events","type":"User","site_admin":false},"node_id":"RE_kwDOGI1GZc4DAuFi","tag_name":"1.2.3b","target_commitish":"1.x","name":"1.2.3b","draft":false,"prerelease":true,"created_at":"2021-09-30T04:10:46Z","published_at":"2021-09-30T04:12:34Z","assets":[],"tarball_url":"https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext/tarball/1.2.3b","zipball_url":"https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext/zipball/1.2.3b","body":"","short_description_html":null,"is_short_description_html_truncated":false}},"public":true,"created_at":"2021-09-30T04:12:34Z"},{"id":"18215875182","type":"PushEvent","actor":{"id":87429507,"login":"Bamboue","display_login":"Bamboue","gravatar_id":"","url":"https://api.github.com/users/Bamboue","avatar_url":"https://avatars.githubusercontent.com/u/87429507?"},"repo":{"id":411909030,"name":"Bamboue/github-slideshow","url":"https://api.github.com/repos/Bamboue/github-slideshow"},"payload":{"push_id":8046687100,"size":1,"distinct_size":1,"ref":"refs/heads/my-slide","head":"2c29a4a54b24ad481af6cacd05c11aea12508c8b","before":"f18d347dbe6061e80a705058ed79d452d3a10447","commits":[{"sha":"2c29a4a54b24ad481af6cacd05c11aea12508c8b","author":{"email":"87429507+Bamboue@users.noreply.github.com","name":"Bamboue"},"message":"Update 0000-01-02-Bamboue.md","distinct":true,"url":"https://api.github.com/repos/Bamboue/github-slideshow/commits/2c29a4a54b24ad481af6cacd05c11aea12508c8b"}]},"public":true,"created_at":"2021-09-30T04:12:34Z"},{"id":"18215875175","type":"PullRequestEvent","actor":{"id":5118689,"login":"apoorv74","display_login":"apoorv74","gravatar_id":"","url":"https://api.github.com/users/apoorv74","avatar_url":"https://avatars.githubusercontent.com/u/5118689?"},"repo":{"id":325038688,"name":"CivicDataLab/civicdatalab.github.io","url":"https://api.github.com/repos/CivicDataLab/civicdatalab.github.io"},"payload":{"action":"opened","number":132,"pull_request":{"url":"https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/pulls/132","id":746315990,"node_id":"PR_kwDOE1-yYM4se-DW","html_url":"https://github.com/CivicDataLab/civicdatalab.github.io/pull/132","di ...

# %% [markdown]
# ## 响应二进制内容

# %%
r.content
# Out:
# b'[{"id":"18215875178","type":"ReleaseEvent","actor":{"id":48498042,"login":"juliancasaburi","display_login":"juliancasaburi","gravatar_id":"","url":"https://api.github.com/users/juliancasaburi","avatar_url":"https://avatars.githubusercontent.com/u/48498042?"},"repo":{"id":411911781,"name":"juliancasaburi/flysystem-google-drive-ext","url":"https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext"},"payload":{"action":"published","release":{"url":"https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext/releases/50520418","assets_url":"https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext/releases/50520418/assets","upload_url":"https://uploads.github.com/repos/juliancasaburi/flysystem-google-drive-ext/releases/50520418/assets{?name,label}","html_url":"https://github.com/juliancasaburi/flysystem-google-drive-ext/releases/tag/1.2.3b","id":50520418,"author":{"login":"juliancasaburi","id":48498042,"node_id":"MDQ6VXNlcjQ4NDk4MDQy","avatar_url":"https://avatars.githubusercontent.com/u/48498042?v=4","gravatar_id":"","url":"https://api.github.com/users/juliancasaburi","html_url":"https://github.com/juliancasaburi","followers_url":"https://api.github.com/users/juliancasaburi/followers","following_url":"https://api.github.com/users/juliancasaburi/following{/other_user}","gists_url":"https://api.github.com/users/juliancasaburi/gists{/gist_id}","starred_url":"https://api.github.com/users/juliancasaburi/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/juliancasaburi/subscriptions","organizations_url":"https://api.github.com/users/juliancasaburi/orgs","repos_url":"https://api.github.com/users/juliancasaburi/repos","events_url":"https://api.github.com/users/juliancasaburi/events{/privacy}","received_events_url":"https://api.github.com/users/juliancasaburi/received_events","type":"User","site_admin":false},"node_id":"RE_kwDOGI1GZc4DAuFi","tag_name":"1.2.3b","target_commitish":"1.x","name":"1.2.3b","draft":false,"prerelease":true,"created_at":"2021-09-30T04:10:46Z","published_at":"2021-09-30T04:12:34Z","assets":[],"tarball_url":"https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext/tarball/1.2.3b","zipball_url":"https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext/zipball/1.2.3b","body":"","short_description_html":null,"is_short_description_html_truncated":false}},"public":true,"created_at":"2021-09-30T04:12:34Z"},{"id":"18215875182","type":"PushEvent","actor":{"id":87429507,"login":"Bamboue","display_login":"Bamboue","gravatar_id":"","url":"https://api.github.com/users/Bamboue","avatar_url":"https://avatars.githubusercontent.com/u/87429507?"},"repo":{"id":411909030,"name":"Bamboue/github-slideshow","url":"https://api.github.com/repos/Bamboue/github-slideshow"},"payload":{"push_id":8046687100,"size":1,"distinct_size":1,"ref":"refs/heads/my-slide","head":"2c29a4a54b24ad481af6cacd05c11aea12508c8b","before":"f18d347dbe6061e80a705058ed79d452d3a10447","commits":[{"sha":"2c29a4a54b24ad481af6cacd05c11aea12508c8b","author":{"email":"87429507+Bamboue@users.noreply.github.com","name":"Bamboue"},"message":"Update 0000-01-02-Bamboue.md","distinct":true,"url":"https://api.github.com/repos/Bamboue/github-slideshow/commits/2c29a4a54b24ad481af6cacd05c11aea12508c8b"}]},"public":true,"created_at":"2021-09-30T04:12:34Z"},{"id":"18215875175","type":"PullRequestEvent","actor":{"id":5118689,"login":"apoorv74","display_login":"apoorv74","gravatar_id":"","url":"https://api.github.com/users/apoorv74","avatar_url":"https://avatars.githubusercontent.com/u/5118689?"},"repo":{"id":325038688,"name":"CivicDataLab/civicdatalab.github.io","url":"https://api.github.com/repos/CivicDataLab/civicdatalab.github.io"},"payload":{"action":"opened","number":132,"pull_request":{"url":"https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/pulls/132","id":746315990,"node_id":"PR_kwDOE1-yYM4se-DW","html_url":"https://github.com/CivicDataLab/civicdatalab.github.io/pull/132","d ...

# %% [markdown]
# ## JSON内容响应

# %%
r.json()
# Out:
# [{'id': '18215875178',
#   'type': 'ReleaseEvent',
#   'actor': {'id': 48498042,
#    'login': 'juliancasaburi',
#    'display_login': 'juliancasaburi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/juliancasaburi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48498042?'},
#   'repo': {'id': 411911781,
#    'name': 'juliancasaburi/flysystem-google-drive-ext',
#    'url': 'https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext'},
#   'payload': {'action': 'published',
#    'release': {'url': 'https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext/releases/50520418',
#     'assets_url': 'https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext/releases/50520418/assets',
#     'upload_url': 'https://uploads.github.com/repos/juliancasaburi/flysystem-google-drive-ext/releases/50520418/assets{?name,label}',
#     'html_url': 'https://github.com/juliancasaburi/flysystem-google-drive-ext/releases/tag/1.2.3b',
#     'id': 50520418,
#     'author': {'login': 'juliancasaburi',
#      'id': 48498042,
#      'node_id': 'MDQ6VXNlcjQ4NDk4MDQy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/48498042?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/juliancasaburi',
#      'html_url': 'https://github.com/juliancasaburi',
#      'followers_url': 'https://api.github.com/users/juliancasaburi/followers',
#      'following_url': 'https://api.github.com/users/juliancasaburi/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/juliancasaburi/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/juliancasaburi/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/juliancasaburi/subscriptions',
#      'organizations_url': 'https://api.github.com/users/juliancasaburi/orgs',
#      'repos_url': 'https://api.github.com/users/juliancasaburi/repos',
#      'events_url': 'https://api.github.com/users/juliancasaburi/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/juliancasaburi/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'node_id': 'RE_kwDOGI1GZc4DAuFi',
#     'tag_name': '1.2.3b',
#     'target_commitish': '1.x',
#     'name': '1.2.3b',
#     'draft': False,
#     'prerelease': True,
#     'created_at': '2021-09-30T04:10:46Z',
#     'published_at': '2021-09-30T04:12:34Z',
#     'assets': [],
#     'tarball_url': 'https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext/tarball/1.2.3b',
#     'zipball_url': 'https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext/zipball/1.2.3b',
#     'body': '',
#     'short_description_html': None,
#     'is_short_description_html_truncated': False}},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z'},
#  {'id': '18215875182',
#   'type': 'PushEvent',
#   'actor': {'id': 87429507,
#    'login': 'Bamboue',
#    'display_login': 'Bamboue',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Bamboue',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87429507?'},
#   'repo': {'id': 411909030,
#    'name': 'Bamboue/github-slideshow',
#    'url': 'https://api.github.com/repos/Bamboue/github-slideshow'},
#   'payload': {'push_id': 8046687100,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/my-slide',
#    'head': '2c29a4a54b24ad481af6cacd05c11aea12508c8b',
#    'before': 'f18d347dbe6061e80a705058ed79d452d3a10447',
#    'commits': [{'sha': '2c29a4a54b24ad481af6cacd05c11aea12508c8b',
#      'author': {'email': '87429507+Bamboue@users.noreply.github.com',
#       'name': 'Bamboue'},
#      'message': 'Update 0000-01-02-Bamboue.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Bamboue/github-slideshow/commits/2c29a4a54b24ad481af6cacd05c11aea12508c8b'}]},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z'},
#  {'id': '18215875175',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 5118689,
#    'login': 'apoorv74',
#    'display_login': 'apoorv74',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/apoorv74',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5118689?'},
#   'repo': {'id': 325038688,
#    'name': 'CivicDataLab/civicdatalab.github.io',
#    'url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io'},
#   'payload': {'action': 'opened',
#    'number': 132,
#    'pull_request': {'url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/pulls/132',
#     'id': 746315990,
#     'node_id': 'PR_kwDOE1-yYM4se-DW',
#     'html_url': 'https://github.com/CivicDataLab/civicdatalab.github.io/pull/132',
#     'diff_url': 'https://github.com/CivicDataLab/civicdatalab.github.io/pull/132.diff',
#     'patch_url': 'https://github.com/CivicDataLab/civicdatalab.github.io/pull/132.patch',
#     'issue_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/issues/132',
#     'number': 132,
#     'state': 'open',
#     'locked': False,
#     'title': 'Update profile picture - AA',
#     'user': {'login': 'apoorv74',
#      'id': 5118689,
#      'node_id': 'MDQ6VXNlcjUxMTg2ODk=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5118689?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/apoorv74',
#      'html_url': 'https://github.com/apoorv74',
#      'followers_url': 'https://api.github.com/users/apoorv74/followers',
#      'following_url': 'https://api.github.com/users/apoorv74/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/apoorv74/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/apoorv74/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/apoorv74/subscriptions',
#      'organizations_url': 'https://api.github.com/users/apoorv74/orgs',
#      'repos_url': 'https://api.github.com/users/apoorv74/repos',
#      'events_url': 'https://api.github.com/users/apoorv74/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/apoorv74/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2021-09-30T04:12:34Z',
#     'updated_at': '2021-09-30T04:12:34Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': {'login': 'apoorv74',
#      'id': 5118689,
#      'node_id': 'MDQ6VXNlcjUxMTg2ODk=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5118689?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/apoorv74',
#      'html_url': 'https://github.com/apoorv74',
#      'followers_url': 'https://api.github.com/users/apoorv74/followers',
#      'following_url': 'https://api.github.com/users/apoorv74/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/apoorv74/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/apoorv74/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/apoorv74/subscriptions',
#      'organizations_url': 'https://api.github.com/users/apoorv74/orgs',
#      'repos_url': 'https://api.github.com/users/apoorv74/repos',
#      'events_url': 'https://api.github.com/users/apoorv74/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/apoorv74/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'apoorv74',
#       'id': 5118689,
#       'node_id': 'MDQ6VXNlcjUxMTg2ODk=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/5118689?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/apoorv74',
#       'html_url': 'https://github.com/apoorv74',
#       'followers_url': 'https://api.github.com/users/apoorv74/followers',
#       'following_url': 'https://api.github.com/users/apoorv74/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/apoorv74/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/apoorv74/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/apoorv74/subscriptions',
#       'organizations_url': 'https://api.github.com/users/apoorv74/orgs',
#       'repos_url': 'https://api.github.com/users/apoorv74/repos',
#       'events_url': 'https://api.github.com/users/apoorv74/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/apoorv74/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/pulls/132/commits',
#     'review_comments_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/pulls/132/comments',
#     'review_comment_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/issues/132/comments',
#     'statuses_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/statuses/a8bb7ccacaac62ea5a02d49aa13baea6cdc2069a',
#     'head': {'label': 'CivicDataLab:aa-profile',
#      'ref': 'aa-profile',
#      'sha': 'a8bb7ccacaac62ea5a02d49aa13baea6cdc2069a',
#      'user': {'login': 'CivicDataLab',
#       'id': 37977551,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM3OTc3NTUx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/37977551?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/CivicDataLab',
#       'html_url': 'https://github.com/CivicDataLab',
#       'followers_url': 'https://api.github.com/users/CivicDataLab/followers',
#       'following_url': 'https://api.github.com/users/CivicDataLab/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/CivicDataLab/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/CivicDataLab/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/CivicDataLab/subscriptions',
#       'organizations_url': 'https://api.github.com/users/CivicDataLab/orgs',
#       'repos_url': 'https://api.github.com/users/CivicDataLab/repos',
#       'events_url': 'https://api.github.com/users/CivicDataLab/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/CivicDataLab/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 325038688,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMjUwMzg2ODg=',
#       'name': 'civicdatalab.github.io',
#       'full_name': 'CivicDataLab/civicdatalab.github.io',
#       'private': False,
#       'owner': {'login': 'CivicDataLab',
#        'id': 37977551,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM3OTc3NTUx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/37977551?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/CivicDataLab',
#        'html_url': 'https://github.com/CivicDataLab',
#        'followers_url': 'https://api.github.com/users/CivicDataLab/followers',
#        'following_url': 'https://api.github.com/users/CivicDataLab/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/CivicDataLab/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/CivicDataLab/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/CivicDataLab/subscriptions',
#        'organizations_url': 'https://api.github.com/users/CivicDataLab/orgs',
#        'repos_url': 'https://api.github.com/users/CivicDataLab/repos',
#        'events_url': 'https://api.github.com/users/CivicDataLab/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/CivicDataLab/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/CivicDataLab/civicdatalab.github.io',
#       'description': 'CDL Website 2.0',
#       'fork': False,
#       'url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io',
#       'forks_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/forks',
#       'keys_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/teams',
#       'hooks_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/hooks',
#       'issue_events_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/events',
#       'assignees_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/tags',
#       'blobs_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/languages',
#       'stargazers_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/stargazers',
#       'contributors_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/contributors',
#       'subscribers_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/subscribers',
#       'subscription_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/subscription',
#       'commits_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/merges',
#       'archive_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/downloads',
#       'issues_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/deployments',
#       'created_at': '2020-12-28T14:49:00Z',
#       'updated_at': '2021-09-14T04:22:04Z',
#       'pushed_at': '2021-09-30T04:11:56Z',
#       'git_url': 'git://github.com/CivicDataLab/civicdatalab.github.io.git',
#       'ssh_url': 'git@github.com:CivicDataLab/civicdatalab.github.io.git',
#       'clone_url': 'https://github.com/CivicDataLab/civicdatalab.github.io.git',
#       'svn_url': 'https://github.com/CivicDataLab/civicdatalab.github.io',
#       'homepage': 'https://civicdatalab.in',
#       'size': 402884,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'CivicDataLab:master',
#      'ref': 'master',
#      'sha': '34a4b927c8d044b412ad03d3de3a13a97296df6c',
#      'user': {'login': 'CivicDataLab',
#       'id': 37977551,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM3OTc3NTUx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/37977551?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/CivicDataLab',
#       'html_url': 'https://github.com/CivicDataLab',
#       'followers_url': 'https://api.github.com/users/CivicDataLab/followers',
#       'following_url': 'https://api.github.com/users/CivicDataLab/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/CivicDataLab/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/CivicDataLab/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/CivicDataLab/subscriptions',
#       'organizations_url': 'https://api.github.com/users/CivicDataLab/orgs',
#       'repos_url': 'https://api.github.com/users/CivicDataLab/repos',
#       'events_url': 'https://api.github.com/users/CivicDataLab/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/CivicDataLab/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 325038688,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMjUwMzg2ODg=',
#       'name': 'civicdatalab.github.io',
#       'full_name': 'CivicDataLab/civicdatalab.github.io',
#       'private': False,
#       'owner': {'login': 'CivicDataLab',
#        'id': 37977551,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM3OTc3NTUx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/37977551?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/CivicDataLab',
#        'html_url': 'https://github.com/CivicDataLab',
#        'followers_url': 'https://api.github.com/users/CivicDataLab/followers',
#        'following_url': 'https://api.github.com/users/CivicDataLab/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/CivicDataLab/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/CivicDataLab/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/CivicDataLab/subscriptions',
#        'organizations_url': 'https://api.github.com/users/CivicDataLab/orgs',
#        'repos_url': 'https://api.github.com/users/CivicDataLab/repos',
#        'events_url': 'https://api.github.com/users/CivicDataLab/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/CivicDataLab/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/CivicDataLab/civicdatalab.github.io',
#       'description': 'CDL Website 2.0',
#       'fork': False,
#       'url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io',
#       'forks_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/forks',
#       'keys_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/teams',
#       'hooks_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/hooks',
#       'issue_events_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/events',
#       'assignees_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/tags',
#       'blobs_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/languages',
#       'stargazers_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/stargazers',
#       'contributors_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/contributors',
#       'subscribers_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/subscribers',
#       'subscription_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/subscription',
#       'commits_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/merges',
#       'archive_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/downloads',
#       'issues_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/deployments',
#       'created_at': '2020-12-28T14:49:00Z',
#       'updated_at': '2021-09-14T04:22:04Z',
#       'pushed_at': '2021-09-30T04:11:56Z',
#       'git_url': 'git://github.com/CivicDataLab/civicdatalab.github.io.git',
#       'ssh_url': 'git@github.com:CivicDataLab/civicdatalab.github.io.git',
#       'clone_url': 'https://github.com/CivicDataLab/civicdatalab.github.io.git',
#       'svn_url': 'https://github.com/CivicDataLab/civicdatalab.github.io',
#       'homepage': 'https://civicdatalab.in',
#       'size': 402884,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/pulls/132'},
#      'html': {'href': 'https://github.com/CivicDataLab/civicdatalab.github.io/pull/132'},
#      'issue': {'href': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/issues/132'},
#      'comments': {'href': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/issues/132/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/pulls/132/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/pulls/132/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/CivicDataLab/civicdatalab.github.io/statuses/a8bb7ccacaac62ea5a02d49aa13baea6cdc2069a'}},
#     'author_association': 'MEMBER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 0,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z',
#   'org': {'id': 37977551,
#    'login': 'CivicDataLab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CivicDataLab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37977551?'}},
#  {'id': '18215875188',
#   'type': 'DeleteEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 349105574,
#    'name': 'xembly/workflow-manager',
#    'url': 'https://api.github.com/repos/xembly/workflow-manager'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/types/node-16.10.1',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z',
#   'org': {'id': 55761343,
#    'login': 'xembly',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/xembly',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55761343?'}},
#  {'id': '18215875174',
#   'type': 'WatchEvent',
#   'actor': {'id': 695352,
#    'login': 'jasoncmcg',
#    'display_login': 'jasoncmcg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jasoncmcg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/695352?'},
#   'repo': {'id': 119918032,
#    'name': 'jivesearch/jivesearch',
#    'url': 'https://api.github.com/repos/jivesearch/jivesearch'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z',
#   'org': {'id': 8783463,
#    'login': 'jivesearch',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/jivesearch',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8783463?'}},
#  {'id': '18215875189',
#   'type': 'CreateEvent',
#   'actor': {'id': 48498042,
#    'login': 'juliancasaburi',
#    'display_login': 'juliancasaburi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/juliancasaburi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48498042?'},
#   'repo': {'id': 411911781,
#    'name': 'juliancasaburi/flysystem-google-drive-ext',
#    'url': 'https://api.github.com/repos/juliancasaburi/flysystem-google-drive-ext'},
#   'payload': {'ref': '1.2.3b',
#    'ref_type': 'tag',
#    'master_branch': '2.x',
#    'description': 'Flysystem adapter for Google Drive with seamless virtual<=>display path translation',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z'},
#  {'id': '18215875171',
#   'type': 'PushEvent',
#   'actor': {'id': 89167251,
#    'login': 'bryankr22',
#    'display_login': 'bryankr22',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bryankr22',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89167251?'},
#   'repo': {'id': 399656429,
#    'name': 'bryankr22/VTN_Front',
#    'url': 'https://api.github.com/repos/bryankr22/VTN_Front'},
#   'payload': {'push_id': 8046687084,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'aa3a005347b14eef9f356813acf670ea5e1bdaf0',
#    'before': '55aedfe59c371624890b087b8ca24d1b252de6de',
#    'commits': [{'sha': '7409c9dd0f76bb553f9b2995f6a2472ef2d425da',
#      'author': {'email': '9ortizcamilo@gmail.com', 'name': 'Camilo Ortiz'},
#      'message': 'Reset password',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/bryankr22/VTN_Front/commits/7409c9dd0f76bb553f9b2995f6a2472ef2d425da'},
#     {'sha': 'aa3a005347b14eef9f356813acf670ea5e1bdaf0',
#      'author': {'email': '89167251+bryankr22@users.noreply.github.com',
#       'name': 'bryankr22'},
#      'message': 'Merge pull request #67 from bryankr22/bugfix/reset-password\n\nReset password',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bryankr22/VTN_Front/commits/aa3a005347b14eef9f356813acf670ea5e1bdaf0'}]},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z'},
#  {'id': '18215875183',
#   'type': 'CreateEvent',
#   'actor': {'id': 91300925,
#    'login': 'NateBlackk',
#    'display_login': 'NateBlackk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NateBlackk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91300925?'},
#   'repo': {'id': 411918950,
#    'name': 'NateBlackk/HTML-and-CSS',
#    'url': 'https://api.github.com/repos/NateBlackk/HTML-and-CSS'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'HTML and CSS video repository',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z'},
#  {'id': '18215875162',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 86929735,
#    'name': 'Lombiq/Orchard',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard'},
#   'payload': {'push_id': 8046687087,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/fileformatter',
#    'head': '30f963299d90cb8ee4c7b19bb2369ea085fc724b',
#    'before': '30f963299d90cb8ee4c7b19bb2369ea085fc724b',
#    'commits': []},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '18215875172',
#   'type': 'PushEvent',
#   'actor': {'id': 80741322,
#    'login': 'debdeb18',
#    'display_login': 'debdeb18',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/debdeb18',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80741322?'},
#   'repo': {'id': 408454973,
#    'name': 'kellygabriela/CompareIt',
#    'url': 'https://api.github.com/repos/kellygabriela/CompareIt'},
#   'payload': {'push_id': 8046687094,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '56de2c13ea152fe91102d34c5945567ef9145186',
#    'before': 'bc85910d019ccf88d84376563418f2db170144a0',
#    'commits': [{'sha': '56de2c13ea152fe91102d34c5945567ef9145186',
#      'author': {'email': '80741322+debdeb18@users.noreply.github.com',
#       'name': 'debdeb18'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kellygabriela/CompareIt/commits/56de2c13ea152fe91102d34c5945567ef9145186'}]},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z'},
#  {'id': '18215875150',
#   'type': 'PushEvent',
#   'actor': {'id': 80210205,
#    'login': 'dwenpark',
#    'display_login': 'dwenpark',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dwenpark',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80210205?'},
#   'repo': {'id': 403949552,
#    'name': 'SeniorSociety/Modak_Backend',
#    'url': 'https://api.github.com/repos/SeniorSociety/Modak_Backend'},
#   'payload': {'push_id': 8046687086,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature/jenkins-notification2',
#    'head': '9c58a1fb36f5a712c9fa9506f5eb07f2c5f28c7a',
#    'before': '3d1f7f8a3b8ba52502c7b8f80a61521895b29303',
#    'commits': [{'sha': '9c58a1fb36f5a712c9fa9506f5eb07f2c5f28c7a',
#      'author': {'email': 'dwenup@gmail.com', 'name': 'dwenpark'},
#      'message': 'test1',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SeniorSociety/Modak_Backend/commits/9c58a1fb36f5a712c9fa9506f5eb07f2c5f28c7a'}]},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z',
#   'org': {'id': 90176478,
#    'login': 'SeniorSociety',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/SeniorSociety',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90176478?'}},
#  {'id': '18215875164',
#   'type': 'CreateEvent',
#   'actor': {'id': 52343461,
#    'login': 'alhelal958',
#    'display_login': 'alhelal958',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alhelal958',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52343461?'},
#   'repo': {'id': 411918569,
#    'name': 'alhelal958/git-test',
#    'url': 'https://api.github.com/repos/alhelal958/git-test'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z'},
#  {'id': '18215875163',
#   'type': 'CreateEvent',
#   'actor': {'id': 70184743,
#    'login': 'EzequielRT',
#    'display_login': 'EzequielRT',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EzequielRT',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70184743?'},
#   'repo': {'id': 411918948,
#    'name': 'EzequielRT/projeto-sales-web-mvc',
#    'url': 'https://api.github.com/repos/EzequielRT/projeto-sales-web-mvc'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z'},
#  {'id': '18215875144',
#   'type': 'ForkEvent',
#   'actor': {'id': 26791223,
#    'login': 'willjwon',
#    'display_login': 'willjwon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/willjwon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26791223?'},
#   'repo': {'id': 13886476,
#    'name': 'zsh-users/zsh-autosuggestions',
#    'url': 'https://api.github.com/repos/zsh-users/zsh-autosuggestions'},
#   'payload': {'forkee': {'id': 411918951,
#     'node_id': 'R_kgDOGI1iZw',
#     'name': 'zsh-autosuggestions',
#     'full_name': 'willjwon/zsh-autosuggestions',
#     'private': False,
#     'owner': {'login': 'willjwon',
#      'id': 26791223,
#      'node_id': 'MDQ6VXNlcjI2NzkxMjIz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/26791223?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/willjwon',
#      'html_url': 'https://github.com/willjwon',
#      'followers_url': 'https://api.github.com/users/willjwon/followers',
#      'following_url': 'https://api.github.com/users/willjwon/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/willjwon/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/willjwon/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/willjwon/subscriptions',
#      'organizations_url': 'https://api.github.com/users/willjwon/orgs',
#      'repos_url': 'https://api.github.com/users/willjwon/repos',
#      'events_url': 'https://api.github.com/users/willjwon/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/willjwon/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/willjwon/zsh-autosuggestions',
#     'description': 'Fish-like autosuggestions for zsh',
#     'fork': True,
#     'url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions',
#     'forks_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/forks',
#     'keys_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/teams',
#     'hooks_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/hooks',
#     'issue_events_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/events',
#     'assignees_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/tags',
#     'blobs_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/languages',
#     'stargazers_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/stargazers',
#     'contributors_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/contributors',
#     'subscribers_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/subscribers',
#     'subscription_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/subscription',
#     'commits_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/merges',
#     'archive_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/downloads',
#     'issues_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/willjwon/zsh-autosuggestions/deployments',
#     'created_at': '2021-09-30T04:12:33Z',
#     'updated_at': '2021-09-29T18:19:57Z',
#     'pushed_at': '2021-09-18T10:20:49Z',
#     'git_url': 'git://github.com/willjwon/zsh-autosuggestions.git',
#     'ssh_url': 'git@github.com:willjwon/zsh-autosuggestions.git',
#     'clone_url': 'https://github.com/willjwon/zsh-autosuggestions.git',
#     'svn_url': 'https://github.com/willjwon/zsh-autosuggestions',
#     'homepage': None,
#     'size': 573,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z',
#   'org': {'id': 567410,
#    'login': 'zsh-users',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/zsh-users',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/567410?'}},
#  {'id': '18215875117',
#   'type': 'PushEvent',
#   'actor': {'id': 55980680,
#    'login': 'ashwon12',
#    'display_login': 'ashwon12',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ashwon12',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55980680?'},
#   'repo': {'id': 410575425,
#    'name': 'ashwon12/Reading-a-Book',
#    'url': 'https://api.github.com/repos/ashwon12/Reading-a-Book'},
#   'payload': {'push_id': 8046687078,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '207e7b5954eb184250058999deb28263141eea73',
#    'before': '91c653d0bf7c3b7b03c2508cb05376479d8c033f',
#    'commits': [{'sha': '207e7b5954eb184250058999deb28263141eea73',
#      'author': {'email': '55980680+ashwon12@users.noreply.github.com',
#       'name': 'JJAE WON'},
#      'message': '2-3. UI에서 코루틴 디스패처 사용하기',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ashwon12/Reading-a-Book/commits/207e7b5954eb184250058999deb28263141eea73'}]},
#   'public': True,
#   'created_at': '2021-09-30T04:12:34Z'},
#  {'id': '18215875129',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 349105574,
#    'name': 'xembly/workflow-manager',
#    'url': 'https://api.github.com/repos/xembly/workflow-manager'},
#   'payload': {'action': 'closed',
#    'number': 76,
#    'pull_request': {'url': 'https://api.github.com/repos/xembly/workflow-manager/pulls/76',
#     'id': 743076497,
#     'node_id': 'PR_kwDOFM7tps4sSnKR',
#     'html_url': 'https://github.com/xembly/workflow-manager/pull/76',
#     'diff_url': 'https://github.com/xembly/workflow-manager/pull/76.diff',
#     'patch_url': 'https://github.com/xembly/workflow-manager/pull/76.patch',
#     'issue_url': 'https://api.github.com/repos/xembly/workflow-manager/issues/76',
#     'number': 76,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump @types/node from 16.7.1 to 16.10.1',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [@types/node](https://github.com/DefinitelyTyped/DefinitelyTyped/tree/HEAD/types/node) from 16.7.1 to 16.10.1.\n<details>\n<summary>Commits</summary>\n<ul>\n<li>See full diff in <a href="https://github.com/DefinitelyTyped/DefinitelyTyped/commits/HEAD/types/node">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=@types/node&package-manager=npm_and_yarn&previous-version=16.7.1&new-version=16.10.1)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n\n\n</details>',
#     'created_at': '2021-09-27T04:14:05Z',
#     'updated_at': '2021-09-30T04:12:33Z',
#     'closed_at': '2021-09-30T04:12:33Z',
#     'merged_at': None,
#     'merge_commit_sha': '022aefc33e2bdbe58e74b2d3b9f8aca25657ff1c',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 2888482041,
#       'node_id': 'MDU6TGFiZWwyODg4NDgyMDQx',
#       'url': 'https://api.github.com/repos/xembly/workflow-manager/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/xembly/workflow-manager/pulls/76/commits',
#     'review_comments_url': 'https://api.github.com/repos/xembly/workflow-manager/pulls/76/comments',
#     'review_comment_url': 'https://api.github.com/repos/xembly/workflow-manager/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/xembly/workflow-manager/issues/76/comments',
#     'statuses_url': 'https://api.github.com/repos/xembly/workflow-manager/statuses/d23045fc6be155df219ae732fa11992946524830',
#     'head': {'label': 'xembly:dependabot/npm_and_yarn/types/node-16.10.1',
# ...
#       'contributors_url': 'https://api.github.com/repos/bryankr22/VTN_Front/contributors',
#       'subscribers_url': 'https://api.github.com/repos/bryankr22/VTN_Front/subscribers',
#       'subscription_url': 'https://api.github.com/repos/bryankr22/VTN_Front/subscription',
#       'commits_url': 'https://api.github.com/repos/bryankr22/VTN_Front/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/bryankr22/VTN_Front/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/bryankr22/VTN_Front/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/bryankr22/VTN_Front/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/bryankr22/VTN_Front/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/bryankr22/VTN_Front/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/bryankr22/VTN_Front/merges',
#       'archive_url': 'https://api.github.com/repos/bryankr22/VTN_Front/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/bryankr22/VTN_Front/downloads',
#       'issues_url': 'https://api.github.com/repos/bryankr22/VTN_Front/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/bryankr22/VTN_Front/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/bryankr22/VTN_Front/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/bryankr22/VTN_Front/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/bryankr22/VTN_Front/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/bryankr22/VTN_Front/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/bryankr22/VTN_Front/deployments',
#       'created_at': '2021-08-25T01:47:22Z',
#       'updated_at': '2021-09-28T15:40:57Z',
#       'pushed_at': '2021-09-30T04:12:33Z',
#       'git_url': 'git://github.com/bryankr22/VTN_Front.git',
#       'ssh_url': 'git@github.com:bryankr22/VTN_Front.git',
#       'clone_url': 'https://github.com/bryankr22/VTN_Front.git',
#       'svn_url': 'https://github.com/bryankr22/VTN_Front',
#       'homepage': 'vtn-front-nine.vercel.app',
#       'size': 2450,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 1,
#       'default_branch': 'main'}},
#     'base': {'label': 'bryankr22:main',
#      'ref': 'main',
#      'sha': '55aedfe59c371624890b087b8ca24d1b252de6de',
#      'user': {'login': 'bryankr22',
#       'id': 89167251,
#       'node_id': 'MDQ6VXNlcjg5MTY3MjUx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/89167251?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/bryankr22',
#       'html_url': 'https://github.com/bryankr22',
#       'followers_url': 'https://api.github.com/users/bryankr22/followers',
#       'following_url': 'https://api.github.com/users/bryankr22/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/bryankr22/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/bryankr22/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/bryankr22/subscriptions',
#       'organizations_url': 'https://api.github.com/users/bryankr22/orgs',
#       'repos_url': 'https://api.github.com/users/bryankr22/repos',
#       'events_url': 'https://api.github.com/users/bryankr22/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/bryankr22/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 399656429,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzOTk2NTY0Mjk=',
#       'name': 'VTN_Front',
#       'full_name': 'bryankr22/VTN_Front',
#       'private': False,
#       'owner': {'login': 'bryankr22',
#        'id': 89167251,
#        'node_id': 'MDQ6VXNlcjg5MTY3MjUx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/89167251?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/bryankr22',
#        'html_url': 'https://github.com/bryankr22',
#        'followers_url': 'https://api.github.com/users/bryankr22/followers',
#        'following_url': 'https://api.github.com/users/bryankr22/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/bryankr22/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/bryankr22/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/bryankr22/subscriptions',
#        'organizations_url': 'https://api.github.com/users/bryankr22/orgs',
#        'repos_url': 'https://api.github.com/users/bryankr22/repos',
#        'events_url': 'https://api.github.com/users/bryankr22/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/bryankr22/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/bryankr22/VTN_Front',
#       'description': 'FrontEnd repository',
#       'fork': False,
#       'url': 'https://api.github.com/repos/bryankr22/VTN_Front',
#       'forks_url': 'https://api.github.com/repos/bryankr22/VTN_Front/forks',
#       'keys_url': 'https://api.github.com/repos/bryankr22/VTN_Front/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/bryankr22/VTN_Front/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/bryankr22/VTN_Front/teams',
#       'hooks_url': 'https://api.github.com/repos/bryankr22/VTN_Front/hooks',
#       'issue_events_url': 'https://api.github.com/repos/bryankr22/VTN_Front/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/bryankr22/VTN_Front/events',
#       'assignees_url': 'https://api.github.com/repos/bryankr22/VTN_Front/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/bryankr22/VTN_Front/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/bryankr22/VTN_Front/tags',
#       'blobs_url': 'https://api.github.com/repos/bryankr22/VTN_Front/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/bryankr22/VTN_Front/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/bryankr22/VTN_Front/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/bryankr22/VTN_Front/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/bryankr22/VTN_Front/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/bryankr22/VTN_Front/languages',
#       'stargazers_url': 'https://api.github.com/repos/bryankr22/VTN_Front/stargazers',
#       'contributors_url': 'https://api.github.com/repos/bryankr22/VTN_Front/contributors',
#       'subscribers_url': 'https://api.github.com/repos/bryankr22/VTN_Front/subscribers',
#       'subscription_url': 'https://api.github.com/repos/bryankr22/VTN_Front/subscription',
#       'commits_url': 'https://api.github.com/repos/bryankr22/VTN_Front/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/bryankr22/VTN_Front/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/bryankr22/VTN_Front/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/bryankr22/VTN_Front/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/bryankr22/VTN_Front/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/bryankr22/VTN_Front/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/bryankr22/VTN_Front/merges',
#       'archive_url': 'https://api.github.com/repos/bryankr22/VTN_Front/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/bryankr22/VTN_Front/downloads',
#       'issues_url': 'https://api.github.com/repos/bryankr22/VTN_Front/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/bryankr22/VTN_Front/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/bryankr22/VTN_Front/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/bryankr22/VTN_Front/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/bryankr22/VTN_Front/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/bryankr22/VTN_Front/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/bryankr22/VTN_Front/deployments',
#       'created_at': '2021-08-25T01:47:22Z',
#       'updated_at': '2021-09-28T15:40:57Z',
#       'pushed_at': '2021-09-30T04:12:33Z',
#       'git_url': 'git://github.com/bryankr22/VTN_Front.git',
#       'ssh_url': 'git@github.com:bryankr22/VTN_Front.git',
#       'clone_url': 'https://github.com/bryankr22/VTN_Front.git',
#       'svn_url': 'https://github.com/bryankr22/VTN_Front',
#       'homepage': 'vtn-front-nine.vercel.app',
#       'size': 2450,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 1,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/bryankr22/VTN_Front/pulls/67'},
#      'html': {'href': 'https://github.com/bryankr22/VTN_Front/pull/67'},
#      'issue': {'href': 'https://api.github.com/repos/bryankr22/VTN_Front/issues/67'},
#      'comments': {'href': 'https://api.github.com/repos/bryankr22/VTN_Front/issues/67/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/bryankr22/VTN_Front/pulls/67/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/bryankr22/VTN_Front/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/bryankr22/VTN_Front/pulls/67/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/bryankr22/VTN_Front/statuses/7409c9dd0f76bb553f9b2995f6a2472ef2d425da'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'bryankr22',
#      'id': 89167251,
#      'node_id': 'MDQ6VXNlcjg5MTY3MjUx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/89167251?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bryankr22',
#      'html_url': 'https://github.com/bryankr22',
#      'followers_url': 'https://api.github.com/users/bryankr22/followers',
#      'following_url': 'https://api.github.com/users/bryankr22/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bryankr22/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bryankr22/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bryankr22/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bryankr22/orgs',
#      'repos_url': 'https://api.github.com/users/bryankr22/repos',
#      'events_url': 'https://api.github.com/users/bryankr22/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bryankr22/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 209,
#     'deletions': 22,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2021-09-30T04:12:33Z'},
#  {'id': '18215875046',
#   'type': 'DeleteEvent',
#   'actor': {'id': 8952081,
#    'login': 'AviVahl',
#    'display_login': 'AviVahl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AviVahl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8952081?'},
#   'repo': {'id': 189427748,
#    'name': 'wixplosives/engine',
#    'url': 'https://api.github.com/repos/wixplosives/engine'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/types/react-17.0.25',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-30T04:12:33Z',
#   'org': {'id': 20948122,
#    'login': 'wixplosives',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/wixplosives',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20948122?'}},
#  {'id': '18215875062',
#   'type': 'CreateEvent',
#   'actor': {'id': 70184743,
#    'login': 'EzequielRT',
#    'display_login': 'EzequielRT',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EzequielRT',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70184743?'},
#   'repo': {'id': 411918948,
#    'name': 'EzequielRT/projeto-sales-web-mvc',
#    'url': 'https://api.github.com/repos/EzequielRT/projeto-sales-web-mvc'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-30T04:12:33Z'},
#  {'id': '18215875028',
#   'type': 'PushEvent',
#   'actor': {'id': 37929162,
#    'login': 'mergify[bot]',
#    'display_login': 'mergify',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mergify[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37929162?'},
#   'repo': {'id': 325273683,
#    'name': 'shunkakinoki/shunkakinoki.com',
#    'url': 'https://api.github.com/repos/shunkakinoki/shunkakinoki.com'},
#   'payload': {'push_id': 8046687031,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '3a1c32a66059b87cb4229d21daa0c1206ffe6bb3',
#    'before': '078fb5fb3d813e8c6dde59a48141880656ea955f',
#    'commits': [{'sha': 'fb9d16a25d995c74100a7c73f2583721ae02233f',
#      'author': {'email': 'bot@renovateapp.com', 'name': 'Renovate Bot'},
#      'message': 'fix(deps): update dependency autoprefixer to ^10.3.6',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shunkakinoki/shunkakinoki.com/commits/fb9d16a25d995c74100a7c73f2583721ae02233f'},
#     {'sha': '3a1c32a66059b87cb4229d21daa0c1206ffe6bb3',
#      'author': {'email': '37929162+mergify[bot]@users.noreply.github.com',
#       'name': 'mergify[bot]'},
#      'message': 'Merge pull request #210 from shunkakinoki/renovate/autoprefixer-10.x\n\nfix(deps): update dependency autoprefixer to ^10.3.6',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shunkakinoki/shunkakinoki.com/commits/3a1c32a66059b87cb4229d21daa0c1206ffe6bb3'}]},
#   'public': True,
#   'created_at': '2021-09-30T04:12:33Z'},
#  {'id': '18215875034',
#   'type': 'PushEvent',
#   'actor': {'id': 68729501,
#    'login': 'mina-heo',
#    'display_login': 'mina-heo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mina-heo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68729501?'},
#   'repo': {'id': 399380262,
#    'name': 'TmaxSoftOfficial/HyperFrameOE-Nginx',
#    'url': 'https://api.github.com/repos/TmaxSoftOfficial/HyperFrameOE-Nginx'},
#   'payload': {'push_id': 8046687038,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'da30bfd8980035050718442b6906da8efaf489a3',
#    'before': 'f68606447a048e8bf51b6292bf6ae501714e2b51',
#    'commits': [{'sha': 'da30bfd8980035050718442b6906da8efaf489a3',
#      'author': {'email': '68729501+mina-heo@users.noreply.github.com',
#       'name': 'mina-heo'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TmaxSoftOfficial/HyperFrameOE-Nginx/commits/da30bfd8980035050718442b6906da8efaf489a3'}]},
#   'public': True,
#   'created_at': '2021-09-30T04:12:33Z',
#   'org': {'id': 64761391,
#    'login': 'TmaxSoftOfficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/TmaxSoftOfficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64761391?'}}]

# %% [markdown]
# ## 原始内容响应
# 需要打开数据流

# %%
r = requests.get('https://api.github.com/events', stream=True)
# Out:
# b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03'

# %%
r.raw

# %%
r.raw.read(10)
# Out:
# b'\xed}\x89v\xdbF\xb6\xed\xaf\xa0'

# %% [markdown]
# ## 自定义请求头

# %%
url = 'https://api.github.com/some/endpoint'
headers = {'user-agent': 'my-app/0.0.1'}
r = requests.get(url, headers=headers)

# %% [markdown]
# ## 为POST请求传递更多数据（例如表格数据等）

# %% [markdown]
# 1. Post请求能为Url传递参为 params
# 2. 为网页数据（如表格等）传递参数 data
# 3. 提交json数据 json
# 4. 为请求提交文件 files

# %%
payload = {'key1': 'value1', 'key2': 'value2'}

r = requests.post("https://httpbin.org/post", data=payload)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-61554792-6062fa430a3a280452cb1b73"
#   },
#   "json": null,
#   "origin": "211.137.244.58",
#   "url": "https://httpbin.org/post"
# }

# %%
payload_tuples = [('key1', 'value1'), ('key1', 'value2')]
r1 = requests.post('https://httpbin.org/post', data=payload_tuples)

payload_dict = {'key1': ['value1', 'value2']}
r2 = requests.post('https://httpbin.org/post', data=payload_dict)

# %% [markdown]
# ## 响应状态码

# %%
r.status_code
# Out:
# 200

# %%
bad_r = requests.get('https://httpbin.org/status/404')
bad_r.status_code
# Out:
# 404

# %% [markdown]
# ### 抛出请求错误

# %%
bad_r.raise_for_status()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipykernel_113444/4074610556.py in <module>
# ----> 1 bad_r.raise_for_status()
#
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/requests/models.py in raise_for_status(self)
#     951
#     952         if http_error_msg:
# --> 953             raise HTTPError(http_error_msg, response=self)
#     954
#     955     def close(self):
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://httpbin.org/status/404

# %% [markdown]
# ## 服务器响应头

# %%
r.headers
# Out:
# {'Date': 'Thu, 30 Sep 2021 05:13:54 GMT', 'Content-Type': 'application/json', 'Content-Length': '506', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
r.headers['Content-Length']
# Out:
# '506'

# %%
r.headers['Content-Type']
# Out:
# 'application/json'

# %% [markdown]
# ## Cookies

# %%
url = 'https://httpbin.org/cookies'
cookies = dict(cookies_are='working')
r = requests.get(url, cookies=cookies)
r.text
# Out:
# '{\n  "cookies": {\n    "cookies_are": "working"\n  }\n}\n'

# %% [markdown]
# ## 设置请求超时

# %%
requests.get('https://github.com/', timeout=0.01)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         conn = self._new_conn()
#     359         hostname = self.host
#
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     178         except SocketTimeout:
# --> 179             raise ConnectTimeoutError(
#     180                 self,
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x7f4173d9d1c0>, 'Connection to github.com timed out. (connect timeout=0.01)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f4173d9d1c0>, 'Connection to github.com timed out. (connect timeout=0.01)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# /tmp/ipykernel_113444/3435677069.py in <module>
# ----> 1 requests.get('https://github.com/', timeout=0.01)
#
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/Learning_python/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     502                 # TODO: Remove this in 3.0.0: see #2811
#     503                 if not isinstance(e.reason, NewConnectionError):
# --> 504                     raise ConnectTimeout(e, request=request)
#     505
#     506             if isinstance(e.reason, ResponseError):
#
# ConnectTimeout: HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f4173d9d1c0>, 'Connection to github.com timed out. (connect timeout=0.01)'))

# %% [markdown]
# ## 抛出错误和重定向、历史等详见使用手册

# %%
url = "https://docs.python-requests.org/en/latest/user/quickstart/"
rp = requests.get(url)
rp.text
# Out:
# '\n<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN"\n  "http://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">\n\n<html xmlns="http://www.w3.org/1999/xhtml" lang="en">\n  <head>\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n    <title>Quickstart &#8212; Requests 2.26.0 documentation</title>\n    <link rel="stylesheet" href="../../_static/alabaster.css" type="text/css" />\n    <link rel="stylesheet" href="../../_static/pygments.css" type="text/css" />\n    <link rel="stylesheet" type="text/css" href="https://assets.readthedocs.org/static/css/badge_only.css" />\n    <script type="text/javascript" id="documentation_options" data-url_root="../../" src="../../_static/documentation_options.js"></script>\n    <script type="text/javascript" src="../../_static/jquery.js"></script>\n    <script type="text/javascript" src="../../_static/underscore.js"></script>\n    <script type="text/javascript" src="../../_static/doctools.js"></script>\n    <script type="text/javascript" src="../../_static/language_data.js"></script>\n    <script async="async" type="text/javascript" src="https://assets.readthedocs.org/static/javascript/readthedocs-doc-embed.js"></script>\n    <link rel="canonical" href="https://docs.python-requests.org/en/latest/user/quickstart.html" />\n    <link rel="index" title="Index" href="../../genindex/" />\n    <link rel="search" title="Search" href="../../search/" />\n    <link rel="next" title="Advanced Usage" href="../advanced/" />\n    <link rel="prev" title="Installation of Requests" href="../install/" />\n   \n  <link rel="stylesheet" href="../../_static/custom.css" type="text/css" />\n  \n  \n  <meta name="viewport" content="width=device-width, initial-scale=0.9, maximum-scale=0.9" />\n\n  \n<!-- RTD Extra Head -->\n\n<link rel="stylesheet" href="https://assets.readthedocs.org/static/css/readthedocs-doc-embed.css" type="text/css" />\n\n<script type="application/json" id="READTHEDOCS_DATA">{"ad_free": false, "api_host": "https://readthedocs.org", "build_date": "2021-09-21T23:22:49Z", "builder": "sphinx", "canonical_url": null, "commit": "94f9f735", "docroot": "/docs/", "features": {"docsearch_disabled": false}, "global_analytics_code": "UA-17997319-1", "language": "en", "page": "user/quickstart", "programming_language": "py", "project": "requests", "proxied_api_host": "/_", "source_suffix": ".rst", "subprojects": {"requests-docs-cn": "https://docs.python-requests.org/zh_CN/latest/", "requests-docs-de": "https://docs.python-requests.org/de/latest/", "requests-docs-es": "https://docs.python-requests.org/es/latest/", "requests-docs-it": "https://docs.python-requests.org/projects/it/it/latest/", "requests-docs-pl": "https://docs.python-requests.org/pl/latest/", "requests-docs-pt": "https://docs.python-requests.org/pt_BR/latest/", "requests-html": "https://docs.python-requests.org/projects/requests-html/en/latest/", "requests3": "https://docs.python-requests.org/projects/3/"}, "theme": "alabaster", "user_analytics_code": "", "version": "latest"}</script>\n\n<!--\nUsing this variable directly instead of using `JSON.parse` is deprecated.\nThe READTHEDOCS_DATA global variable will be removed in the future.\n-->\n<script type="text/javascript">\nREADTHEDOCS_DATA = JSON.parse(document.getElementById(\'READTHEDOCS_DATA\').innerHTML);\n</script>\n\n<script type="text/javascript" src="https://assets.readthedocs.org/static/javascript/readthedocs-analytics.js" async="async"></script>\n\n<!-- end RTD <extrahead> -->\n</head><body>\n  \n\n    <div class="document">\n      <div class="documentwrapper">\n        <div class="bodywrapper">\n          \n\n          <div class="body" role="main">\n            \n  <div class="section" id="quickstart">\n<span id="id1"></span><h1>Quickstart<a class="headerlink" href="#quickstart" title="Permalink to this headline">Â¶</a></h1>\n<span class="target" id="module-requests.models"></span><p>Eager ...
